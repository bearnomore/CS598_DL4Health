# %%
from __future__ import division
import argparse
import math
import numpy as np

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import pickle
from tqdm import tqdm

from sklearn.metrics import roc_auc_score, classification_report

# %% [markdown]
# ### Model Construction

# %%
class RNN(nn.Module):
    def __init__(self, epochs=5, batchsize=50, vocabsize=5, embsize=100):
        super(RNN, self).__init__()
        self.epochs = 5
        self.batchsize = batchsize
        self.vocabsize = vocabsize
        self.embsize = embsize

        self.emb_icd = nn.Linear(vocabsize_icd, embsize_icd)

        self.rnn = nn.LSTM(input_size=embsize, hidden_size=embsize, num_layers=1)
        self.out = nn.Linear(embsize, 1)
        self.sig = nn.Sigmoid()

    def forward(self, input_icd, hidden=None, force=True, steps=0):
        if force or steps == 0: steps = len(input_icd)
        outputs = Variable(torch.zeros(steps, 1, 1))

        input_icd = F.relu(self.emb_icd(input_icd))

        inputs = input_icd

        inputs = inputs.view(inputs.size()[0],1,inputs.size()[1])
        outputs, hidden = self.rnn(inputs, hidden)
        outputs = self.out(outputs)
        return outputs.squeeze(), hidden

    def predict(self, input_icd):
        out, hid = self.forward(input_icd, None)
        return self.sig(out[-1]).data

# %% [markdown]
# ### Data loading

# %%
DATA_PATH = '/Users/shunfan/Developer/MIMIC/output2/'

n_epochs = 5
vocabsize_icd = 942
vocabsize = vocabsize_icd

embsize_icd = 50
embsize = embsize_icd

input_seqs_icd = pickle.load(open(DATA_PATH + 'MIMICIIIPROCESSED.3digitICD9.seqs', 'rb'))
input_seqs_fullicd = pickle.load(open(DATA_PATH + 'MIMICIIIPROCESSED.seqs', 'rb'))

labels = pickle.load(open(DATA_PATH + 'MIMICIIIPROCESSED.morts', 'rb'))

# %% [markdown]
# ### Model Training

# %%
trainratio = 0.7
validratio = 0.1
testratio = 0.2

trainlindex = int(len(input_seqs_icd)*trainratio)
validlindex = int(len(input_seqs_icd)*(trainratio + validratio))

print('Data prepared..')

def convert_to_one_hot(code_seqs, len):
    new_code_seqs = []
    for code_seq in code_seqs:
        one_hot_vec = np.zeros(len)
        for code in code_seq:
            one_hot_vec[code] = 1
        new_code_seqs.append(one_hot_vec)
    return np.array(new_code_seqs)
# Out:
# Data prepared..

# %%
import time

start = time.process_time()

print('Starting training..')

batchsize = 50

best_aucrocs = []
for run in range(10):
    print('Run', run)

    perm = np.random.permutation(len(input_seqs_icd))
    rinput_seqs_icd = [input_seqs_icd[i] for i in perm]
    rinput_seqs_fullicd = [input_seqs_fullicd[i] for i in perm]
    rlabels = [labels[i] for i in perm]
    rlabels = torch.tensor(rlabels)

    train_input_seqs_icd = rinput_seqs_icd[:trainlindex]
    train_labels = rlabels[:trainlindex]
    train_labels = train_labels.reshape(train_labels.shape[0],1)

    valid_input_seqs_icd = rinput_seqs_icd[trainlindex:validlindex]
    valid_labels = rlabels[trainlindex:validlindex]

    test_input_seqs_icd = rinput_seqs_icd[validlindex:]
    test_input_seqs_fullicd = rinput_seqs_fullicd[validlindex:]

    test_labels = rlabels[validlindex:]

    n_iters = len(train_input_seqs_icd)

    model = RNN(n_epochs, 1, vocabsize, embsize)
    criterion = nn.BCEWithLogitsLoss(reduction='sum')
    optimizer = optim.Adam(model.parameters(), lr=0.01)

    aucrocs = []

    for epoch in range(n_epochs):

        epoch_loss = 0

        print('Epoch', (epoch+1))

        for i in (range(0, n_iters, batchsize)):
            batch_icd = train_input_seqs_icd[i:i+batchsize]

            batch_train_labels = train_labels[i:i+batchsize]

            optimizer.zero_grad()
            losses = []

            for j in range(len(batch_icd)):
                icd_onehot = convert_to_one_hot(batch_icd[j], vocabsize_icd)

                icd_inputs = Variable(torch.from_numpy(icd_onehot).float())

                targets = Variable(batch_train_labels[j].float())
                
                # Use teacher forcing 50% of the time
                force = random.random() < 0.5
                outputs, hidden = model(icd_inputs, None, force)

                #print outputs[-1], targets
                loss = criterion(outputs[-1].view(1), targets)
                losses.append(loss)
#                 losses.append(criterion(outputs[-1], targets))

            loss = sum(losses)/len(batch_icd)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.data

        #print(epoch, epoch_loss)

        ## Validation phase
        vpredictions = np.zeros(len(valid_input_seqs_icd))
        for i in range(len(valid_input_seqs_icd)):
            test_input_icd = Variable(torch.from_numpy(convert_to_one_hot(valid_input_seqs_icd[i], vocabsize_icd)).float())
            vpredictions[i] = model.predict(test_input_icd)

        print("Validation AUC_ROC: ", roc_auc_score(valid_labels, vpredictions))

        ## Testing phase
        predictions = np.zeros(len(test_input_seqs_icd))

        # ICD_wise_corr = np.zeros(5)
        # meds_wise_corr = np.zeros(5)
        # labs_wise_corr = np.zeros(5)
        # ICD_wise_tot = np.zeros(5)
        # meds_wise_tot = np.zeros(5)
        # labs_wise_tot = np.zeros(5)

        for i in range(len(test_input_seqs_icd)):
            test_input_icd = Variable(torch.from_numpy(convert_to_one_hot(test_input_seqs_icd[i], vocabsize_icd)).float())
            predictions[i] = model.predict(test_input_icd)

            # ICD_wise_corr[get_avg(test_input_seqs_icd[i], 'i')] += int((predictions[i]>0.5)*1 == test_labels[i])
            # ICD_wise_tot[get_avg(test_input_seqs_icd[i], 'i')] += 1

            # meds_wise_corr[get_avg(test_input_seqs_meds[i], 'm')] += int((predictions[i]>0.5)*1 == test_labels[i])
            # meds_wise_tot[get_avg(test_input_seqs_meds[i], 'm')] += 1

            # labs_wise_corr[get_avg(test_input_seqs_labs[i], 'l')] += int((predictions[i]>0.5)*1 == test_labels[i])
            # labs_wise_tot[get_avg(test_input_seqs_labs[i], 'l')] += 1

        print("Test AUC_ROC: ", roc_auc_score(test_labels, predictions))

        aucrocs.append(roc_auc_score(test_labels, predictions))
        actual_predictions = (predictions>0.5)*1
        print(classification_report(test_labels, actual_predictions))

    best_aucrocs.append(max(aucrocs))

print("Average AUCROC:", np.mean(best_aucrocs), "+/-", np.std(best_aucrocs))

end = time.process_time()
print('The training is complete!')
print('The time used is: ', end - start)
# Out:
# Starting training..
# Run 0
# Epoch 1
# Validation AUC_ROC:  0.8441402012493922
# Test AUC_ROC:  0.7991820973520962
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80       937
#            1       0.69      0.56      0.62       571
#
#     accuracy                           0.74      1508
#    macro avg       0.72      0.70      0.71      1508
# weighted avg       0.73      0.74      0.73      1508
#
# Epoch 2
# Validation AUC_ROC:  0.8396887741742416
# Test AUC_ROC:  0.796182248746325
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       937
#            1       0.68      0.59      0.63       571
#
#     accuracy                           0.74      1508
#    macro avg       0.72      0.71      0.72      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 3
# Validation AUC_ROC:  0.8284218007705831
# Test AUC_ROC:  0.7848744082074363
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.80       937
#            1       0.68      0.55      0.61       571
#
#     accuracy                           0.73      1508
#    macro avg       0.72      0.70      0.70      1508
# weighted avg       0.73      0.73      0.72      1508
#
# Epoch 4
# Validation AUC_ROC:  0.7994613399169566
# Test AUC_ROC:  0.7730974324660251
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.79       937
#            1       0.67      0.55      0.60       571
#
#     accuracy                           0.73      1508
#    macro avg       0.71      0.69      0.70      1508
# weighted avg       0.72      0.73      0.72      1508
#
# Epoch 5
# Validation AUC_ROC:  0.795339094003666
# Test AUC_ROC:  0.7717161937621839
#               precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77       937
#            1       0.62      0.69      0.65       571
#
#     accuracy                           0.72      1508
#    macro avg       0.71      0.71      0.71      1508
# weighted avg       0.73      0.72      0.72      1508
#
# Run 1
# Epoch 1
# Validation AUC_ROC:  0.8393780450499521
# Test AUC_ROC:  0.8118727706910103
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81       952
#            1       0.73      0.45      0.56       556
#
#     accuracy                           0.74      1508
#    macro avg       0.74      0.68      0.69      1508
# weighted avg       0.74      0.74      0.72      1508
#
# Epoch 2
# Validation AUC_ROC:  0.824560356340792
# Test AUC_ROC:  0.7972726860528384
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81       952
#            1       0.70      0.49      0.58       556
#
#     accuracy                           0.73      1508
#    macro avg       0.72      0.68      0.69      1508
# weighted avg       0.73      0.73      0.72      1508
#
# Epoch 3
# Validation AUC_ROC:  0.8046542166247603
# Test AUC_ROC:  0.7888428752796082
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.81       952
#            1       0.72      0.41      0.52       556
#
#     accuracy                           0.72      1508
#    macro avg       0.72      0.66      0.66      1508
# weighted avg       0.72      0.72      0.70      1508
#
# Epoch 4
# Validation AUC_ROC:  0.7915525744428445
# Test AUC_ROC:  0.7837324678072669
#               precision    recall  f1-score   support
#
#            0       0.73      0.88      0.79       952
#            1       0.67      0.44      0.53       556
#
#     accuracy                           0.71      1508
#    macro avg       0.70      0.66      0.66      1508
# weighted avg       0.71      0.71      0.70      1508
#
# Epoch 5
# Validation AUC_ROC:  0.7744891031045521
# Test AUC_ROC:  0.7659650640831872
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76       952
#            1       0.59      0.64      0.61       556
#
#     accuracy                           0.70      1508
#    macro avg       0.68      0.69      0.68      1508
# weighted avg       0.71      0.70      0.70      1508
#
# Run 2
# Epoch 1
# Validation AUC_ROC:  0.8159848923732065
# Test AUC_ROC:  0.8211734336733616
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.80       971
#            1       0.63      0.72      0.67       537
#
#     accuracy                           0.75      1508
#    macro avg       0.73      0.74      0.73      1508
# weighted avg       0.76      0.75      0.75      1508
#
# Epoch 2
# Validation AUC_ROC:  0.8180915335595466
# Test AUC_ROC:  0.8154890329806472
#               precision    recall  f1-score   support
#
#            0       0.84      0.72      0.77       971
#            1       0.59      0.75      0.66       537
#
#     accuracy                           0.73      1508
#    macro avg       0.72      0.73      0.72      1508
# weighted avg       0.75      0.73      0.73      1508
#
# Epoch 3
# Validation AUC_ROC:  0.8066630051236523
# Test AUC_ROC:  0.8035717367915356
#               precision    recall  f1-score   support
#
#            0       0.85      0.67      0.75       971
#            1       0.57      0.78      0.66       537
#
#     accuracy                           0.71      1508
#    macro avg       0.71      0.73      0.71      1508
# weighted avg       0.75      0.71      0.72      1508
#
# Epoch 4
# Validation AUC_ROC:  0.7821319208805759
# Test AUC_ROC:  0.7946328057427022
#               precision    recall  f1-score   support
#
#            0       0.85      0.65      0.73       971
#            1       0.55      0.79      0.65       537
#
#     accuracy                           0.70      1508
#    macro avg       0.70      0.72      0.69      1508
# weighted avg       0.74      0.70      0.70      1508
#
# Epoch 5
# Validation AUC_ROC:  0.7814134057616636
# Test AUC_ROC:  0.7884938831322504
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78       971
#            1       0.60      0.66      0.63       537
#
#     accuracy                           0.72      1508
#    macro avg       0.70      0.71      0.70      1508
# weighted avg       0.73      0.72      0.73      1508
#
# Run 3
# Epoch 1
# Validation AUC_ROC:  0.8112146036733625
# Test AUC_ROC:  0.8108660224044839
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       962
#            1       0.64      0.67      0.66       546
#
#     accuracy                           0.74      1508
#    macro avg       0.72      0.73      0.73      1508
# weighted avg       0.75      0.74      0.75      1508
#
# Epoch 2
# Validation AUC_ROC:  0.8044514270751506
# Test AUC_ROC:  0.8020416866570713
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78       962
#            1       0.62      0.69      0.65       546
#
#     accuracy                           0.73      1508
#    macro avg       0.71      0.72      0.72      1508
# weighted avg       0.74      0.73      0.74      1508
#
# Epoch 3
# Validation AUC_ROC:  0.7857928403097294
# Test AUC_ROC:  0.7830717446102061
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79       962
#            1       0.62      0.65      0.63       546
#
#     accuracy                           0.73      1508
#    macro avg       0.71      0.71      0.71      1508
# weighted avg       0.73      0.73      0.73      1508
#
# Epoch 4
# Validation AUC_ROC:  0.7770096884001048
# Test AUC_ROC:  0.768155095078172
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78       962
#            1       0.62      0.62      0.62       546
#
#     accuracy                           0.72      1508
#    macro avg       0.70      0.70      0.70      1508
# weighted avg       0.72      0.72      0.72      1508
#
# Epoch 5
# Validation AUC_ROC:  0.7675980997269293
# Test AUC_ROC:  0.7564178718024872
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74       962
#            1       0.56      0.69      0.62       546
#
#     accuracy                           0.69      1508
#    macro avg       0.68      0.69      0.68      1508
# weighted avg       0.71      0.69      0.70      1508
#
# Run 4
# Epoch 1
# Validation AUC_ROC:  0.8231252730005256
# Test AUC_ROC:  0.8166964906587548
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       925
#            1       0.68      0.70      0.69       583
#
#     accuracy                           0.76      1508
#    macro avg       0.74      0.75      0.75      1508
# weighted avg       0.76      0.76      0.76      1508
#
# Epoch 2
# Validation AUC_ROC:  0.8039282462076062
# Test AUC_ROC:  0.8026665430439015
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80       925
#            1       0.69      0.64      0.66       583
#
#     accuracy                           0.75      1508
#    macro avg       0.74      0.73      0.73      1508
# weighted avg       0.75      0.75      0.75      1508
#
# Epoch 3
# Validation AUC_ROC:  0.7847682364351128
# Test AUC_ROC:  0.7857772008715405
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.77       925
#            1       0.64      0.62      0.63       583
#
#     accuracy                           0.72      1508
#    macro avg       0.70      0.70      0.70      1508
# weighted avg       0.72      0.72      0.72      1508
#
# Epoch 4
# Validation AUC_ROC:  0.7678218444840937
# Test AUC_ROC:  0.7759862778730703
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76       925
#            1       0.61      0.71      0.66       583
#
#     accuracy                           0.72      1508
#    macro avg       0.71      0.71      0.71      1508
# weighted avg       0.73      0.72      0.72      1508
#
# Epoch 5
# Validation AUC_ROC:  0.7554951766822385
# Test AUC_ROC:  0.7825821705066988
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.75       925
#            1       0.60      0.75      0.67       583
#
#     accuracy                           0.71      1508
#    macro avg       0.71      0.72      0.71      1508
# weighted avg       0.73      0.71      0.72      1508
#
# Run 5
# Epoch 1
# Validation AUC_ROC:  0.8011403508771929
# Test AUC_ROC:  0.8065150963918333
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       949
#            1       0.66      0.66      0.66       559
#
#     accuracy                           0.75      1508
#    macro avg       0.73      0.73      0.73      1508
# weighted avg       0.75      0.75      0.75      1508
#
# Epoch 2
# Validation AUC_ROC:  0.7856067251461989
# Test AUC_ROC:  0.8050692660195932
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79       949
#            1       0.64      0.67      0.65       559
#
#     accuracy                           0.74      1508
#    macro avg       0.72      0.72      0.72      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 3
# Validation AUC_ROC:  0.7692616959064327
# Test AUC_ROC:  0.7870029840280042
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78       949
#            1       0.62      0.68      0.65       559
#
#     accuracy                           0.73      1508
#    macro avg       0.71      0.72      0.71      1508
# weighted avg       0.73      0.73      0.73      1508
#
# Epoch 4
# Validation AUC_ROC:  0.7697587719298246
# Test AUC_ROC:  0.7750122056736117
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       949
#            1       0.63      0.64      0.64       559
#
#     accuracy                           0.73      1508
#    macro avg       0.71      0.71      0.71      1508
# weighted avg       0.73      0.73      0.73      1508
#
# Epoch 5
# Validation AUC_ROC:  0.7782456140350877
# Test AUC_ROC:  0.7699272937712421
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78       949
#            1       0.63      0.63      0.63       559
#
#     accuracy                           0.73      1508
#    macro avg       0.71      0.71      0.71      1508
# weighted avg       0.73      0.73      0.73      1508
#
# Run 6
# Epoch 1
# Validation AUC_ROC:  0.8400277642177204
# Test AUC_ROC:  0.8130072620504937
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       913
#            1       0.69      0.71      0.70       595
#
#     accuracy                           0.76      1508
#    macro avg       0.75      0.75      0.75      1508
# weighted avg       0.76      0.76      0.76      1508
#
# Epoch 2
# Validation AUC_ROC:  0.8351232609226265
# Test AUC_ROC:  0.802547700350677
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79       913
#            1       0.68      0.65      0.67       595
#
#     accuracy                           0.74      1508
#    macro avg       0.73      0.73      0.73      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 3
# Validation AUC_ROC:  0.8387692213814987
# Test AUC_ROC:  0.8047382808545105
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.78       913
#            1       0.67      0.65      0.66       595
#
#     accuracy                           0.74      1508
#    macro avg       0.72      0.72      0.72      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 4
# Validation AUC_ROC:  0.8176943495240421
# Test AUC_ROC:  0.790978121807321
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79       913
#            1       0.67      0.65      0.66       595
#
#     accuracy                           0.74      1508
#    macro avg       0.73      0.72      0.72      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 5
# Validation AUC_ROC:  0.8106693922382231
# Test AUC_ROC:  0.7778033447771222
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79       913
#            1       0.68      0.58      0.63       595
#
#     accuracy                           0.73      1508
#    macro avg       0.72      0.70      0.71      1508
# weighted avg       0.73      0.73      0.72      1508
#
# Run 7
# Epoch 1
# Validation AUC_ROC:  0.810880965855499
# Test AUC_ROC:  0.8081634842506942
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79       921
#            1       0.68      0.65      0.66       587
#
#     accuracy                           0.74      1508
#    macro avg       0.73      0.73      0.73      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 2
# Validation AUC_ROC:  0.8101641199773628
# Test AUC_ROC:  0.8097634783316409
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80       921
#            1       0.68      0.66      0.67       587
#
#     accuracy                           0.75      1508
#    macro avg       0.74      0.73      0.73      1508
# weighted avg       0.75      0.75      0.75      1508
#
# Epoch 3
# Validation AUC_ROC:  0.7915638558762498
# Test AUC_ROC:  0.7915031990633098
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78       921
#            1       0.66      0.63      0.64       587
#
#     accuracy                           0.73      1508
#    macro avg       0.71      0.71      0.71      1508
# weighted avg       0.72      0.73      0.72      1508
#
# Epoch 4
# Validation AUC_ROC:  0.7836030937558952
# Test AUC_ROC:  0.7720517103289328
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74       921
#            1       0.59      0.66      0.62       587
#
#     accuracy                           0.69      1508
#    macro avg       0.68      0.69      0.68      1508
# weighted avg       0.70      0.69      0.69      1508
#
# Epoch 5
# Validation AUC_ROC:  0.7621279003961516
# Test AUC_ROC:  0.7635523198064469
#               precision    recall  f1-score   support
#
#            0       0.78      0.69      0.73       921
#            1       0.58      0.69      0.63       587
#
#     accuracy                           0.69      1508
#    macro avg       0.68      0.69      0.68      1508
# weighted avg       0.70      0.69      0.69      1508
#
# Run 8
# Epoch 1
# Validation AUC_ROC:  0.7957045184304399
# Test AUC_ROC:  0.8092214912280702
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.79       900
#            1       0.71      0.60      0.65       608
#
#     accuracy                           0.74      1508
#    macro avg       0.74      0.72      0.72      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 2
# Validation AUC_ROC:  0.7879161712247326
# Test AUC_ROC:  0.8000383771929825
#               precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79       900
#            1       0.70      0.64      0.67       608
#
#     accuracy                           0.74      1508
#    macro avg       0.73      0.73      0.73      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 3
# Validation AUC_ROC:  0.774910820451843
# Test AUC_ROC:  0.7866776315789473
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78       900
#            1       0.68      0.62      0.65       608
#
#     accuracy                           0.73      1508
#    macro avg       0.72      0.71      0.72      1508
# weighted avg       0.73      0.73      0.73      1508
#
# Epoch 4
# Validation AUC_ROC:  0.7715294292508917
# Test AUC_ROC:  0.7765588450292398
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78       900
#            1       0.69      0.59      0.64       608
#
#     accuracy                           0.73      1508
#    macro avg       0.72      0.71      0.71      1508
# weighted avg       0.73      0.73      0.72      1508
#
# Epoch 5
# Validation AUC_ROC:  0.762774970273484
# Test AUC_ROC:  0.7688687865497076
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76       900
#            1       0.66      0.58      0.62       608
#
#     accuracy                           0.71      1508
#    macro avg       0.70      0.69      0.69      1508
# weighted avg       0.71      0.71      0.71      1508
#
# Run 9
# Epoch 1
# Validation AUC_ROC:  0.8030591439513064
# Test AUC_ROC:  0.8223726299197998
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77       925
#            1       0.63      0.77      0.70       583
#
#     accuracy                           0.74      1508
#    macro avg       0.73      0.75      0.73      1508
# weighted avg       0.76      0.74      0.74      1508
#
# Epoch 2
# Validation AUC_ROC:  0.7962501786883149
# Test AUC_ROC:  0.8179055213017479
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77       925
#            1       0.63      0.77      0.69       583
#
#     accuracy                           0.73      1508
#    macro avg       0.73      0.74      0.73      1508
# weighted avg       0.75      0.73      0.74      1508
#
# Epoch 3
# Validation AUC_ROC:  0.7886813178545364
# Test AUC_ROC:  0.8066793380000927
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78       925
#            1       0.65      0.68      0.67       583
#
#     accuracy                           0.74      1508
#    macro avg       0.72      0.73      0.72      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 4
# Validation AUC_ROC:  0.7792691459827106
# Test AUC_ROC:  0.7934986787816977
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       925
#            1       0.66      0.67      0.66       583
#
#     accuracy                           0.74      1508
#    macro avg       0.72      0.73      0.72      1508
# weighted avg       0.74      0.74      0.74      1508
#
# Epoch 5
# Validation AUC_ROC:  0.7703008735037207
# Test AUC_ROC:  0.7838746465161559
#               precision    recall  f1-score   support
#
#            0       0.76      0.81      0.78       925
#            1       0.66      0.60      0.63       583
#
#     accuracy                           0.73      1508
#    macro avg       0.71      0.70      0.71      1508
# weighted avg       0.72      0.73      0.73      1508
#
# Average AUCROC: 0.8120670772701544 +/- 0.006505205401000497
# The training is complete!
# The time used is:  129.994033

# %% [markdown]
# ### Interpretation

# %%
MIMIC_PATH = '/Users/shunfan/Developer/MIMIC/'
out_path = '/Users/shunfan/Developer/MIMIC/output_txt/'


icditems = pickle.load(open(DATA_PATH + 'MIMICIIIPROCESSED.types', 'rb'))
meditems = pickle.load(open(DATA_PATH + 'MIMICIIIPROCESSED.meds.types', 'rb'))
labitems = pickle.load(open(DATA_PATH + 'MIMICIIIPROCESSED.abnlabs.types', 'rb'))

model_name = 'CAE'

interpretation_file = open(out_path + "RNN_CLatent_Interpretations_" + model_name + ".txt", 'w')

# overall_risk_factor_file = open("risk_factors_averaged.txt", "w")


labnames = {}
lab_dict_file = open(MIMIC_PATH + 'D_LABITEMS.csv', 'r')
lab_dict_file.readline()
for line in lab_dict_file:
    tokens = line.strip().split(',')
    labnames[tokens[1].replace('"','')] = tokens[2]
lab_dict_file.close()

icdnames = {}
icd_dict_file = open(MIMIC_PATH + 'D_ICD_DIAGNOSES.csv', 'r')
icd_dict_file.readline()
for line in icd_dict_file:
    tokens = line.strip().split(',')
    icdnames[tokens[1].replace('"','')] = tokens[2]
icd_dict_file.close()

icd_scores = {}
med_scores = {}
lab_scores = {}

icd_totals = {}
med_totals = {}
lab_totals = {}

def get_ICD(icd):
    '''
    Given icd integer index, return the string name of that icd code:
    e.g. get_ICD(1) returns "Hypertension NOS"
    '''
    ret_str = ""
    icd_key_lst = list(icditems.keys())
    icd_val_ind = list(icditems.values())[icd]
    icd_str = icd_key_lst[icd_val_ind]
    actual_key = icd_str.replace(".", "")[2:]
    if actual_key in icdnames:
        ret_str = icdnames[actual_key]
    else:
        ret_str = icd_str
    return ret_str

def get_med(med):
    '''
    Given icd integer index, return the string name of that med code:
    e.g. get_med(1) returns "Phenylephrine HCl"
    '''
    med_key_lst = list(meditems.keys())
    med_val_ind = list(meditems.values())[med]
    ret_str = med_key_lst[med_val_ind]
    return ret_str

def get_lab(lab):
    '''
    Given lab integer index, return the string name of that lab code:
    e.g. get_lab(1) returns "Hemoglobin"
    '''
    lab_key_lst = list(labitems.keys())
    lab_val_ind = list(labitems.values())[lab]
    ret_str = labnames[lab_key_lst[lab_val_ind]]
    return ret_str

# %%
def get_factors(icd_seq, model, actual_score, full_icd):
    potential_test_data = []

    for seq in range(len(icd_seq)):
        for i in range(len(icd_seq[seq])):
            potential_test_data.append(("icd", full_icd[seq][i], seq, icd_seq[:seq]+[icd_seq[seq][:i] + icd_seq[seq][i+1:]]+icd_seq[seq+1:]))

    risk_scores = []

    for pt in potential_test_data:
        test_input_icd = Variable(torch.from_numpy(convert_to_one_hot(pt[3], vocabsize_icd)).float())
        factor_score = actual_score - model.predict(test_input_icd)
        factor = ""
        if pt[0] == 'icd':
            icd_tag = get_ICD(pt[1])
            factor = "ICD-"+icd_tag
            if icd_tag in icd_scores:
                icd_scores[icd_tag] += factor_score
                icd_totals[icd_tag] += 1
            else:
                icd_scores[icd_tag] = factor_score
                icd_totals[icd_tag] = 1
        elif pt[0] == 'med':
            med_tag = get_med(pt[1])
            factor = "Med-"+med_tag
            if med_tag in med_scores:
                med_scores[med_tag] += factor_score
                med_totals[med_tag] += 1
            else:
                med_scores[med_tag] = factor_score
                med_totals[med_tag] = 1
        else:
            lab_tag = get_lab(pt[1])
            factor = "Lab-"+lab_tag
            if lab_tag in lab_scores:
                lab_scores[lab_tag] += factor_score
                lab_totals[lab_tag] += 1
            else:
                lab_scores[lab_tag] = factor_score
                lab_totals[lab_tag] = 1
        risk_scores.append(("Encounter-"+str(pt[2])+": "+factor, factor_score))

    risk_scores.sort(key=lambda tup: tup[1], reverse=True)

    return risk_scores[:10]

# %%
# print "Final testing and interpretations"

interpretation_file = open(out_path + "RNN_Concat_Interpretations.txt", 'w')
predictions = np.zeros(len(test_input_seqs_icd))
for i in (range(len(test_input_seqs_icd))):
    test_input_icd = Variable(torch.from_numpy(convert_to_one_hot(test_input_seqs_icd[i], vocabsize_icd)).float())

    test_score = model.predict(test_input_icd)
    predictions[i] = test_score
    top_risk_factors = get_factors(test_input_seqs_icd[i], model, test_score, test_input_seqs_fullicd[i]) 
    if (test_score>0.5):
        interpretation_file.write("ID: " + str(i) + " True label: "+str(test_labels[i])+"\n")
        for rf in top_risk_factors:
            interpretation_file.write(str(rf)+"\n")
        interpretation_file.write("\n")

interpretation_file.close()
